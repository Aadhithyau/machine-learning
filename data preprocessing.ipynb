# %%
import pandas as pd
import numpy as np
d={'Name':pd.Series(['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], index=labels), 'Score':pd.Series([12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19], index=labels),'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(d,index=labels)
print(df)
print("question 1: specific label c")
print(df.loc[['c']])
# Out:
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# question 1: specific label c
#         Name  Score  attempts qualify
# c  Katherine   16.5         2     yes

# %%
import numpy as np
d={'Name':pd.Series(['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], index=labels), 'Score':pd.Series([12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19], index=labels),'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(d,index=labels)
print(df)
print("question 2. summary of the dataframe")
print(df.describe(include='all'))
# Out:
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# question 2. summary of the dataframe
#              Name      Score   attempts qualify
# count          10   8.000000  10.000000      10
# unique         10        NaN        NaN       2
# top     Anastasia        NaN        NaN     yes
# freq            1        NaN        NaN       5
# mean          NaN  13.562500   1.900000     NaN
# std           NaN   4.693746   0.875595     NaN
# min           NaN   8.000000   1.000000     NaN
# 25%           NaN   9.000000   1.000000     NaN
# 50%           NaN  13.500000   2.000000     NaN
# ...

# %%
import numpy as np
d={'Name':pd.Series(['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], index=labels), 'Score':pd.Series([12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19], index=labels),'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(d,index=labels)
print(df)
print("question 3: first 3 rows")
print(df.head(3))
# Out:
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# question 3: first 3 rows
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
d={'Name':pd.Series(['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], index=labels), 'Score':pd.Series([12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19], index=labels),'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(d,index=labels)
print(df)
print("question 4: name and score column")
result=df[['Name', 'Score']]
print(result)
# Out:
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# question 4: name and score column
#         Name  Score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
d={'Name':pd.Series(['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], index=labels), 'Score':pd.Series([12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19], index=labels),'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(d,index=labels)
print(df)
print("question 5: specific row and column")
result=df.loc[['c','d','e']], [['Name', 'Score']]
print(result)
# Out:
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# question 5: specific row and column
# (        Name  Score  attempts qualify
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no, [['Name', 'Score']])

# %%
d={'Name':pd.Series(['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], index=labels), 'Score':pd.Series([12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19], index=labels),'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(d,index=labels)
print(df)
print("question 6:  rows where attempts are greater than 2")
result=df[df['attempts']>2]
print(result)
# Out:
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# question 6:  rows where attempts are greater than 2
#       Name  Score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %%
d={'Name':pd.Series(['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], index=labels), 'Score':pd.Series([12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19], index=labels),'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(d,index=labels)
print(df)
print("question 7")
rows, cols = df.shape
print(rows)
print(cols)
# Out:
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# question 7
# 10
# 4

# %%
d={'Name':pd.Series(['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], index=labels), 'Score':pd.Series([12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19], index=labels),'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(d,index=labels)
print(df)
print("question 8")
result=df[df['Score'].isnull()]
print(result)
# Out:
#         Name  Score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# question 8
#     Name  Score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no
